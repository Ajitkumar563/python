# %% [markdown]
# ##### Request the user for the number of elements they would like to
# ##### include. After that, continue prompting the user for numbers to form a new list.
#
# ##### Example
# ##### Enter number of elements = 4
# ##### Enter number = 23
# ##### Enter number = 12
# ##### Enter number = -100
# ##### Enter number = 5

# %% [markdown]
# ###

# %% [markdown]
# Output
# [23, 12, -100, 5]

# %%
n  = int(input("enter the no"))

number = []

# Loop
for i in range(n):
    num = int(input("Enter the number ="))
    number.append(num)
    
print(number)
# Out:
# [23, 12, -100, 5]
